# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 

sns.set()

# %%
# loading the data from excel sheet
data = pd.read_excel('/content/cancer patient data sets.xlsx')

#printing the first 5 rows of the dataframe
data.head()
# Out:
#   Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0         P1   33       1              2            4             5
# 1        P10   17       1              3            1             5
# 2       P100   35       1              4            5             6
# 3      P1000   37       1              7            7             7
# 4       P101   46       1              6            8             7
#
#    OccuPational Hazards  Genetic Risk  chronic Lung Disease  Balanced Diet  \
# 0                     4             3                     2              2
# 1                     3             4                     2              2
# 2                     5             5                     4              6
# 3                     7             6                     7              7
# 4                     7             7                     6              7
#
#    ...  Fatigue  Weight Loss  Shortness of Breath  Wheezing  \
# ...

# %%
#number of rows and columns in the dataframe
data.shape
# Out:
# (1000, 25)

# %%
# retrieving the column names/labels
cols = data.keys()
cols
# Out:
# Index(['Patient Id', 'Age', 'Gender', 'Air Pollution', 'Alcohol use',
#        'Dust Allergy', 'OccuPational Hazards', 'Genetic Risk',
#        'chronic Lung Disease', 'Balanced Diet', 'Obesity', 'Smoking',
#        'Passive Smoker', 'Chest Pain', 'Coughing of Blood', 'Fatigue',
#        'Weight Loss', 'Shortness of Breath', 'Wheezing',
#        'Swallowing Difficulty', 'Clubbing of Finger Nails', 'Frequent Cold',
#        'Dry Cough', 'Snoring', 'Level'],
#       dtype='object')

# %%
#getting more information about the dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Patient Id                1000 non-null   object
#  1   Age                       1000 non-null   int64
#  2   Gender                    1000 non-null   int64
#  3   Air Pollution             1000 non-null   int64
#  4   Alcohol use               1000 non-null   int64
#  5   Dust Allergy              1000 non-null   int64
#  6   OccuPational Hazards      1000 non-null   int64
#  7   Genetic Risk              1000 non-null   int64
#  8   chronic Lung Disease      1000 non-null   int64
#  9   Balanced Diet             1000 non-null   int64
#  10  Obesity                   1000 non-null   int64
#  11  Smoking                   1000 non-null   int64
#  12  Passive Smoker            1000 non-null   int64
#  13  Chest Pain                1000 non-null   int64
# ...

# %%
#no. of non-null values in the datafame
data.isnull().value_counts().sum()
# Out:
# 1000

# %%
#getting some statistical measures about the data
data.describe()
# Out:
#                Age       Gender  Air Pollution  Alcohol use  Dust Allergy  \
# count  1000.000000  1000.000000      1000.0000  1000.000000   1000.000000
# mean     37.174000     1.402000         3.8400     4.563000      5.165000
# std      12.005493     0.490547         2.0304     2.620477      1.980833
# min      14.000000     1.000000         1.0000     1.000000      1.000000
# 25%      27.750000     1.000000         2.0000     2.000000      4.000000
# 50%      36.000000     1.000000         3.0000     5.000000      6.000000
# 75%      45.000000     2.000000         6.0000     7.000000      7.000000
# max      73.000000     2.000000         8.0000     8.000000      8.000000
#
#        OccuPational Hazards  Genetic Risk  chronic Lung Disease  \
# count           1000.000000   1000.000000           1000.000000
# mean               4.840000      4.580000              4.380000
# std                2.107805      2.126999              1.848518
# ...

# %%
# distribution of target variable
data['Level'].value_counts()
# Out:
# High      365
# Medium    332
# Low       303
# Name: Level, dtype: int64

# %%
fig , ax = plt.subplots()
ax.scatter(  data['Age'],data['Level'])
ax.set_xlabel("Age")
ax.set_ylabel("Level")
sns.set_palette('rocket')
plt.show()

# %%
#plot for distribution of level wrt gender
sns.countplot(data=data, x="Level", hue="Gender", palette= 'rocket')
# Out:
# <Axes: xlabel='Level', ylabel='count'>

# %%
#Pair plot
sns.pairplot(data, hue='Level', corner=True)

# %%
# transform the values in the 'Level' column into numerical labels. (label_encoder)
from sklearn.preprocessing import LabelEncoder
#creates an instance of label_encoder and assigns to encoder
encoder = LabelEncoder()
#applies the label encoding transformation to the 'Level' column 
data['Level']= encoder.fit_transform(data['Level'])

# %%
#dropping the Patient Id column
data.drop(['Patient Id'],axis=1, inplace=True)

# %%
#generating correlation matrix and its heatmap
correlation = data.corr() #calc corr coeff
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.heatmap(correlation,annot=True,cmap="rocket", annot_kws={"size":7})
plt.show()

# %%
#splitting dataset into training set and testing set
from sklearn.model_selection import train_test_split

X = data.iloc[:, :-1] #selects all rows and columns except the last column using the :-1 indexing
y = data.iloc[:, -1] #selects all rows and only the last column using the -1 indexing

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3 , random_state=42)

# %%
#standardize the features in the training and testing sets
from sklearn.preprocessing import StandardScaler

Scaler = StandardScaler() #creates insatnce and assigns
X_train_scaled=Scaler.fit_transform(X_train) #transforms the training set features
X_test_scaled=Scaler.transform(X_test) #ensures that the testing set is scaled in the same way as the training set

# %%
#training a KNN classification model
from sklearn.neighbors import KNeighborsClassifier

classifier = KNeighborsClassifier()

classifier.fit(X_train_scaled,y_train)
# Out:
# KNeighborsClassifier()

# %%
#making predictions on new, unseen data
ypred = classifier.predict(X_test_scaled)

# %%
#assessing the performance of a classification model
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

result = confusion_matrix(y_test, ypred)
print("Confusion Matrix:")
print(result)

result1 = classification_report(y_test, ypred)
print("Classification Report:")
print (result1)

result2 = accuracy_score(y_test,ypred)
print("Accuracy: ",result2)
# Out:
# Confusion Matrix:
# [[119   0   0]
#  [  0  84   0]
#  [  0   0  97]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       119
#            1       1.00      1.00      1.00        84
#            2       1.00      1.00      1.00        97
#
#     accuracy                           1.00       300
#    macro avg       1.00      1.00      1.00       300
# weighted avg       1.00      1.00      1.00       300
#
# Accuracy:  1.0

# %%
from sklearn.metrics import ConfusionMatrixDisplay

cm = confusion_matrix(y_test, ypred, labels=classifier.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=classifier.classes_ )

plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
disp.plot()
plt.show()
